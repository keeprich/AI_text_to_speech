# %% [markdown]
# <a href="https://colab.research.google.com/github/keeprich/AI_text_to_speech/blob/main/Copy_of_text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
model_id = "runwayml/stable-diffusion-v1-5"
device = "cuda" if torch.cuda.is_available() else "cpu"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
prompt = "Two boys, one in fine clothes and the other in simple, worn-out clothes, playing football joyfully with a rough, old ball."
image = pipe(prompt).images[0]

# Save or display the image
image.save("output.png")
image.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# !pip install gtts pydub

# %%
from gtts import gTTS
from IPython.display import Audio
from pydub import AudioSegment
import os

# %%
def text_to_speech(text, lang='en'):
    tts = gTTS(text=text, lang=lang, slow=False)
    tts.save("output.mp3")
    sound = AudioSegment.from_mp3("output.mp3")
    sound.export("output.wav", format="wav")
    return "output.wav"

text = '''
Roots of Riches: Ancient African Wisdom for Modern Prosperity

Introduction: The Seeds of Wealth
In the vast and diverse continent of Africa, the true roots of riches lie not in material possessions, but in the wisdom passed down through generations. These teachings, embedded in proverbs, stories, and traditions, offer a path to prosperity that transcends time. This book, "Roots of Riches," explores these ancient teachings, revealing how they can guide us in achieving not just financial wealth, but a rich life in every sense of the word.


Chapter 1: The Tree of Life – Understanding True Wealth

1.1 Wealth Beyond Gold
In many African cultures, wealth is not merely defined by the amount of money or gold one possesses. True wealth encompasses health, family, wisdom, and integrity. As the Yoruba proverb says, *"A tree does not move unless there is wind."* This means that wealth, like a tree, is deeply rooted in the soil of one's character and actions.

1.2 The Power of Community
Another key aspect of wealth in African wisdom is the strength of community. In many societies, the well-being of one is tied to the well-being of all. The Swahili saying, *"Unity is strength, division is weakness,"* reminds us that collective prosperity is often greater than individual gain.


Chapter 2: Sowing the Seeds – The Path to Prosperity

2.1 Wisdom in Patience
African proverbs often highlight the importance of patience and timing. The saying, *"Patience can cook a stone,"* teaches that with time, even the most difficult tasks can be accomplished. In the pursuit of wealth, patience allows us to make wiser decisions and avoid the pitfalls of haste.

2.2 Hard Work and Perseverance
Hard work is a recurring theme in African proverbs related to wealth. The Akan proverb, *"By the work of your hands, you shall eat,"* emphasises that wealth is earned through diligent effort. Success is not just a matter of luck but the result of consistent hard work and perseverance.



Chapter 3: The Harvest – Reaping What You Sow

3.1 Honesty and Integrity
In the journey to wealth, honesty and integrity are crucial. The Yoruba proverb, *"The man who is honest, will eat the fruit of his labour,"* underscores that ill-gotten gains are fleeting, while wealth built on honesty endures. Trustworthiness is a cornerstone of lasting prosperity.

3.2 Wisdom in Giving
Generosity is another important aspect of wealth in African culture. The proverb, *"One hand cannot wash itself clean,"* illustrates the interdependence of individuals. By sharing your wealth, you not only help others but also enrich yourself. Generosity creates a cycle of abundance that benefits all.


Chapter 4: Thorns and Weeds – Navigating Challenges

4.1 Deception and Betrayal
While on the path to wealth, one must be wary of deception and betrayal. The Igbo proverb, *"He who throws a stone in the market will hit his relative,"* warns that treachery often harms those close to you, including yourself. Being vigilant and discerning is key to protecting your wealth.

4.2 Overcoming Adversity
Adversity is a part of life, but African wisdom teaches that it can also be a source of growth. The Shona proverb, *"The axe forgets, but the tree remembers,"* suggests that while challenges may leave scars, they also impart valuable lessons. Resilience and adaptability are essential traits for maintaining wealth.


Chapter 5: Passing on the Legacy – Ensuring Future Prosperity

5.1 Teaching the Next Generation
The wealth of wisdom should not end with you; it must be passed on to future generations. The proverb, *"What an elder sees while sitting, a child cannot see even if he climbs a tree,"* highlights the importance of teaching and guiding the younger generation. This ensures that the roots of riches continue to grow deep and strong.

5.2 Building a Lasting Legacy
True wealth is not just about accumulation but also about leaving a legacy. The proverb, *"A good name is better than riches,"* reminds us that how we are remembered is more important than the wealth we leave behind. By living with integrity and generosity, we can create a legacy that enriches future generations.


Conclusion: The Fruit of Wisdom
"Roots of Riches" has taken you on a journey through the ancient wisdom of Africa, revealing timeless principles that can guide you in your quest for prosperity. Remember that wealth is more than just material gain—it is found in the strength of your community, the wisdom of your decisions, and the integrity of your actions. By nurturing these roots, you will cultivate a life that is truly rich in every sense.

'''

output_path = text_to_speech(text, lang='en')

# %%
# !pip install gtts pydub

from gtts import gTTS
from pydub import AudioSegment
from google.colab import files
import os

def text_to_speech(text, lang='en'):
    tts = gTTS(text=text, lang=lang, slow=False)
    tts.save("output.mp3")
    sound = AudioSegment.from_mp3("output.mp3")
    output_path = "Rising_from_the_ashes.wav"
    sound.export(output_path, format="wav")
    return output_path

text = '''




Introduction: Rising from the Ashes

In African culture, the concept of wealth transcends mere material possessions. It is deeply rooted in the values, traditions, and collective wisdom passed down through generations. "From Ashes to Gold" is a journey through these teachings, exploring how African proverbs and stories provide timeless guidance for transforming challenges into opportunities and turning ashes into gold. This wisdom has helped many rises from humble beginnings to achieve true wealth—wealth that encompasses not only financial prosperity but also spiritual fulfilment, community well-being, and a legacy that endures.
We will explore how these teachings can guide us today, offering practical lessons for building a life that is rich in every sense of the word. Whether you are seeking financial success, personal growth, or deeper connections with others, this book will provide you with the insights needed to turn your dreams into reality.


Chapter 1: The Foundation of Wealth

1.1	Wealth in Character

In the African worldview, wealth is first and foremost a matter of character. The Akan proverb, "When character is lost, all is lost," underscores the importance of virtues such as honesty, integrity, and kindness. These traits are the bedrock upon which all other forms of wealth are built. Without a strong moral foundation, any material wealth accumulated is fragile and temporary.
Character is like the roots of a tree—unseen, but vital. It provides the stability needed to weather life’s storms and the strength to support the growth of all other aspects of wealth. In African societies, a person’s reputation and integrity are often valued more highly than their material assets. A good name, as another proverb goes, is worth more than silver and gold.



1.2 The Value of Knowledge
Narrative: Knowledge is a critical component of wealth in African traditions. The Yoruba saying, "Wisdom is like a baobab tree; no one individual can embrace it," suggests that knowledge is vast and cannot be fully possessed by any one person. It must be sought after, shared, and continuously expanded.
In the journey to build wealth, acquiring knowledge—whether through formal education, life experiences, or the wisdom of elders—is indispensable. Knowledge equips individuals with the tools to navigate the complexities of life, make informed decisions, and seize opportunities that others might miss. It is also a form of wealth that can never be taken away, and one that multiplies as it is shared.


Chapter 2: Building Wealth through Community

2.1 The Strength of Unity

Thank you for joining me on this exploration of 'of African Wisdom.' I hope these insights inspire you to live a richer, more fulfilling life, not just in terms of material wealth, but in spirit, community, and integrity. Remember, true prosperity is about more than just what you have—it's about who you are and the legacy you create. Your comments, likes, and shares are incredibly important in helping this channel grow and spread these valuable teachings. Together, we can ensure that this wisdom reaches those who need it most. Until next time, stay wise and stay prosperous!




'''




output_file = text_to_speech(text)
files.download(output_file)

# %%
# !pip install nltk spacy transformers pillow opencv-python moviepy ffmpeg-python gtts pydub librosa numpy matplotlib

# Install ImageMagick
# !apt-get install -y imagemagick

# Install FFmpeg
# !apt-get install -y ffmpeg


# !convert --version  # Verify ImageMagick installation

# !ffmpeg -version  # Verify FFmpeg installation


from moviepy.editor import TextClip, AudioFileClip
from gtts import gTTS
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Video

# Sample text
text = "This is a sample text to video conversion."

# Convert text to speech
tts = gTTS(text)
tts.save("voiceover.mp3")

# Create a text clip (image with text)
text_clip = TextClip(text, fontsize=70, color='white', size=(640, 480), bg_color='black')
text_clip = text_clip.set_duration(10)  # Set duration

# Add audio to video
audio_clip = AudioFileClip("voiceover.mp3")
video_clip = text_clip.set_audio(audio_clip)

# Save final video
output_file = "final_video.mp4"
video_clip.write_videofile(output_file, fps=24)

# Display the video
Video(output_file)
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts imagemagick-6-common
#   imagemagick-6.q16 libdjvulibre-text libdjvulibre21 libfftw3-double3 libgs9 libgs9-common libidn12
#   libijs-0.35 libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libnetpbm10 libwmflite-0.2-7 netpbm
#   poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x imagemagick-doc
#   autotrace cups-bsd | lpr | lprng enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer
#   povray radiance sane-utils texlive-base-bin transfig ufraw-batch libfftw3-bin libfftw3-dev
#   inkscape poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
# ...

# %%
from gtts import gTTS

# The text to be converted to speech
text = '''Tsɔɔ African gbɔmɔ amɛ ni wɔɔ, gbɔlɔ ni yɛ ɔbaa gbɔmɔ wɔɔ heɛ yɛ wɔɔ tsɔɔ atsɔɔ ni yɛ yɛɛmɔ kɛ.
Igbo gbɔmɔ lɛ wɔ yɛ, "Wɔ yɛ wɔhɔ afee ni ekɛ gbɔmɔ ni yɛ yɛ niyɛɛ shishi lɛ mi,"
wɔɔ yɛɛ ji gbɔmɔ ni etsɔ ɛyɛ wɔɔ he amɛ ɔtɔɔ wɔ yɛ wɔɔ.
Gbɔmɔ yɛɛ nɔɔ ji tsɔ ɔnya wɔ, ɛyɛ wɔ kɛ wɔ ni yɛ ɛyɛ ɛyɛ tsɔɔ ɔkɔɔ ni yɛ wɔ yɛɛ.'''

# Creating an audio file
tts = gTTS(text=text, lang='en', slow=False)

# Save the audio file
tts.save("output.mp3")

print("Audio file created successfully!")
# Out:
# Audio file created successfully!

# %%
# !pip install pyttsx3

# %%
import pyttsx3

def text_to_speech(text):
    engine = pyttsx3.init()
    engine.setProperty('rate', 150)  # Speed of speech
    engine.setProperty('volume', 1.0)  # Volume level (0.0 to 1.0)

    voices = engine.getProperty('voices')
    engine.setProperty('voice', voices[1].id)  # Change the index for different voices

    engine.save_to_file(text, 'output.mp3')  # Save to file
    engine.runAndWait()

text = "Introduction: In the heart of Africa..."
text_to_speech(text)
